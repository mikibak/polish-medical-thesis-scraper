# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("doctorates_with_text_without_na_3.csv", sep='|')
df.head()
# Out:
#                                                Title  \
# 0  Czynniki ryzyka zakrzepowo-zatorowego u choryc...
# 1  Analiza czynników wpływających na jakość życia...
# 2  Ocena stopnia regeneracji zębodołów poekstrakc...
# 3  Wykorzystanie innowacyjnych niefarmakologiczny...
# 4  Zastosowanie wirtualnej rzeczywistości w proce...
#
#                                                  URL  \
# 0  https://ppm.edu.pl/info/phd/UMWf110b799b6ba40c...
# 1  https://ppm.edu.pl/info/phd/UMW4a13d3b5a1b5416...
# 2  https://ppm.edu.pl/info/phd/UMW0613c0dbe03f484...
# 3  https://ppm.edu.pl/info/phd/UMW10a21e9a40d749a...
# 4  https://ppm.edu.pl/info/phd/UMWc1586049b9d24d6...
#
#                                                 File  \
# 0  https://ppm.edu.pl/docstore/download/UMWbcd934...
# 1  https://ppm.edu.pl/docstore/download/UMW7e5178...
# 2  https://ppm.edu.pl/docstore/download/UMW4c003c...
# 3  https://ppm.edu.pl/docstore/download/UMWa9e0c4...
# ...

# %%
df
# Out:
#                                                  Title  \
# 0    Czynniki ryzyka zakrzepowo-zatorowego u choryc...
# 1    Analiza czynników wpływających na jakość życia...
# 2    Ocena stopnia regeneracji zębodołów poekstrakc...
# 3    Wykorzystanie innowacyjnych niefarmakologiczny...
# 4    Zastosowanie wirtualnej rzeczywistości w proce...
# ..                                                 ...
# 172  Ocena przydatności niskodawkowej hydrografii T...
# 173  Ocena dynamiki gospodarki wapniowo-fosforanowe...
# 174  Ekspresja metalotioneiny-3 w guzach pierwotnyc...
# 175  Czynniki wpływające na wyniki leczenia raka pł...
# 176  Przeskórna angioplastyka wieńcowa w trybie jed...
#
#                                                    URL  \
# 0    https://ppm.edu.pl/info/phd/UMWf110b799b6ba40c...
# 1    https://ppm.edu.pl/info/phd/UMW4a13d3b5a1b5416...
# 2    https://ppm.edu.pl/info/phd/UMW0613c0dbe03f484...
# 3    https://ppm.edu.pl/info/phd/UMW10a21e9a40d749a...
# ...

# %%
df['Text'][3]
# Out:
# 'Skutkiem wydłużającej się średniej długości życia jest coraz większa powszechność zaburzeń poznawczych w populacji ogólnej. Póki co skuteczność farmakoterapii w ich leczeniu jest ograniczona, dlatego poszukiwane są metody niefarmakologiczne, które mogłyby wspomagać proces farmakologiczny i zatrzymywać progresję objawów związanych z deterioracją poznawczą. Oddziaływanie tych metod opiera się na zjawisku neuroplastyczności mózgu, czyli zdolności tkanki nerwowej do tworzenia nowych połączeń neuronalnych i neurogenezy. 1. Poznanie wyników badań dotyczących efektywności niefarmakologicznych interwencji terapeutycznych, takich jak trening poznawczy i rehabilitacja poznawcza, ukierunkowanych na poprawę sprawności poznawczej osób z chorobą Parkinsona. Przeprowadzone analizy wykazały, że w grupie pacjentów z chorobą Parkinsona trening poznawczy i stymulacja poznawcza przynoszą pożądane efekty, jako że u osób badanych przynajmniej jedna domena poznawcza uległa poprawie po zastosowanej interwe
# ...

# %%
#saving each df['Text'] in a txt file not based on index
for i in range(len(df)):
    with open(f"./text_files/doctorates_3_doc{i}.txt", "w", encoding="utf-8") as file:
        file.write(str(df['Text'][i]))
